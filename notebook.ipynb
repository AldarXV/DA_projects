# %%
from api import remove_watermark

DTYPE = torch.FloatTensor
INPUT_DEPTH = 32
LR = 0.01 
TRAINING_STEPS = 1000
SHOW_STEPS = 50
REG_NOISE = 0.03
MAX_DIM = 128

remove_watermark(
    image_path = '1.jpg',
    mask_path = 'watermarkx.jpg',
    max_dim = MAX_DIM,
    show_step = SHOW_STEPS,
    reg_noise = REG_NOISE,
    input_depth = INPUT_DEPTH,
    lr = LR,
    training_steps = TRAINING_STEPS,
    tqdm_length = 900
)
# Out:
# Setting device to "cpu", since torch is not built with "cuda" support...
# It is recommended to use GPU if possible...
# Visualizing mask overlap...
# Building the model...
#
# Starting training...
# Completed:   0%|                                                                                              …
# Saving final output image to: "1-output.jpg"
